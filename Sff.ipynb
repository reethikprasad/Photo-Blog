# %% [markdown]
# <a href="https://colab.research.google.com/github/reethikprasad/Photo_Blog/blob/master/Sff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install -q kaggle

# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-4c63afda-a724-4040-9c90-0daf68564024" name="files[]" multiple disabled />
#      <output id="result-4c63afda-a724-4040-9c90-0daf68564024">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"reethikprasad","key":"6f7b91d3b245e42741bf5eb42fed01ef"}'}

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
#Change the permissions of the file.
! chmod 600 ~/.kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! kaggle datasets download -d rohitmidha23/food-recognition-challenge
# Out:
# ...
#  97% 417M/431M [00:06<00:00, 59.7MB/s]
# 100% 431M/431M [00:06<00:00, 65.0MB/s]

# %%
# !unzip "/content/food-recognition-challenge.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/train/images/036703.jpg
#   inflating: train/train/images/036706.jpg
#   inflating: train/train/images/036707.jpg
#   inflating: train/train/images/036714.jpg
#   inflating: train/train/images/036753.jpg
#   inflating: train/train/images/036757.jpg
#   inflating: train/train/images/036791.jpg
#   inflating: train/train/images/036797.jpg
#   inflating: train/train/images/036815.jpg
#   inflating: train/train/images/036817.jpg
#   inflating: train/train/images/036818.jpg
#   inflating: train/train/images/036829.jpg
#   inflating: train/train/images/036833.jpg
#   inflating: train/train/images/036834.jpg
#   inflating: train/train/images/036839.jpg
#   inflating: train/train/images/036841.jpg
#   inflating: train/train/images/036853.jpg
#   inflating: train/train/images/036854.jpg
#   inflating: train/train/images/036874.jpg
#   inflating: train/train/images/036875.jpg
#   inflating: train/train/images/036894.jpg
# ...

# %% [markdown]
# # **Getting our workspace ready**

# %%
#importing tensflow
import tensorflow as tf
import tensorflow_hub as hub

print("TF version:", tf.__version__)
print("Hub version:", hub.__version__)

# Check for GPU
print("GPU", "available (YESS!!!!)" if tf.config.list_physical_devices("GPU") else "not available :(")
# Out:
# TF version: 2.2.0-rc2
# Hub version: 0.8.0
# GPU available (YESS!!!!)
